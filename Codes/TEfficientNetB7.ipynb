# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !nvidia-smi
# Out:
# Sun Jul 20 17:54:33 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off |   00000000:00:04.0 Off |                    0 |
# | N/A   33C    P0             44W /  400W |       0MiB /  40960MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
import os

correct_path = '/content/drive/MyDrive/Medical_Data/archive/chest_xray/chest_xray_split'
print(os.listdir(correct_path))
# Out:
# ['train', 'val', 'test']

# %%
print("Train folders:", os.listdir(correct_path + '/train'))
print("Val folders:", os.listdir(correct_path + '/val'))
print("Test folders:", os.listdir(correct_path + '/test'))
# Out:
# Train folders: ['PNEUMONIA', 'NORMAL']
# Val folders: ['PNEUMONIA', 'NORMAL']
# Test folders: ['PNEUMONIA', 'NORMAL']

# %%
import os

base_path = '/content/drive/MyDrive/Medical_Data/archive/chest_xray/chest_xray_split'

splits = ['train', 'val', 'test']
classes = ['PNEUMONIA', 'NORMAL']

for split in splits:
    for cls in classes:
        folder = os.path.join(base_path, split, cls)
        count = len([f for f in os.listdir(folder) if f.lower().endswith(('.jpg', '.jpeg', '.png'))])
        print(f"{split.capitalize()} - {cls}: {count} images")
# Out:
# Train - PNEUMONIA: 3818 images
# Train - NORMAL: 1403 images
# Val - PNEUMONIA: 1135 images
# Val - NORMAL: 418 images
# Test - PNEUMONIA: 1141 images
# Test - NORMAL: 415 images

# %%
# ---------------- Step 1: Imports ---------------- #
import os
import pickle
import pandas as pd
from tensorflow.keras.applications import EfficientNetB7
from tensorflow.keras.applications.efficientnet import preprocess_input as efficientnet_preprocess
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dropout, Dense
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, EarlyStopping, ReduceLROnPlateau

# ✅ Mixed precision (A100 optimization)
from tensorflow.keras import mixed_precision
mixed_precision.set_global_policy('mixed_float16')

# ---------------- Step 2: Config ---------------- #
base_path = '/content/drive/MyDrive/Medical_Data/archive/chest_xray/chest_xray_split'
checkpoint_path = '/content/drive/MyDrive/TEfficientNetB7_checkpoint.keras'
final_model_path = '/content/drive/MyDrive/TEfficientNetB7_final.keras'
history_path = '/content/drive/MyDrive/TEfficientNetB7_history.pkl'
csv_log_path = '/content/drive/MyDrive/TEfficientNetB7_training_log.csv'

epochs = 15
batch_size = 16  # EfficientNetB7 is heavier → reduce batch size
input_shape = (600, 600, 3)  # Required for B7
start_epoch = 0

# ---------------- Step 3: Data Generators ---------------- #
train_datagen = ImageDataGenerator(
    preprocessing_function=efficientnet_preprocess,
    rotation_range=15,
    zoom_range=0.1,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True
)

val_test_datagen = ImageDataGenerator(preprocessing_function=efficientnet_preprocess)

train_generator = train_datagen.flow_from_directory(
    os.path.join(base_path, 'train'),
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='binary'
)

val_generator = val_test_datagen.flow_from_directory(
    os.path.join(base_path, 'val'),
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='binary'
)

# ---------------- Step 4: Build Model ---------------- #
print("🛠 Building new EfficientNetB7 model...")
base_model = EfficientNetB7(weights='imagenet', include_top=False, input_shape=input_shape)
base_model.trainable = False  # Freeze backbone initially

x = GlobalAveragePooling2D()(base_model.output)
x = Dropout(0.5)(x)
x = Dense(128, activation='relu')(x)
x = Dropout(0.3)(x)
output = Dense(1, activation='sigmoid', dtype='float32')(x)  # Force float32 output for numerical stability

model = Model(inputs=base_model.input, outputs=output)
model.compile(optimizer=Adam(1e-4), loss='binary_crossentropy', metrics=['accuracy'])

# ---------------- Step 5: Callbacks ---------------- #
checkpoint_callback = ModelCheckpoint(
    filepath=checkpoint_path,
    save_best_only=False,
    save_weights_only=False,
    save_freq='epoch',
    verbose=1
)

csv_logger = CSVLogger(csv_log_path, append=False)

early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True, verbose=1)

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.3, patience=3, verbose=1)

# ---------------- Step 6: Train Model ---------------- #
history = model.fit(
    train_generator,
    validation_data=val_generator,
    initial_epoch=start_epoch,
    epochs=epochs,
    callbacks=[checkpoint_callback, csv_logger, early_stop, reduce_lr]
)

# ---------------- Step 7: Save Final Model & History ---------------- #
model.save(final_model_path)

with open(history_path, 'wb') as f:
    pickle.dump(history.history, f)

print("✅ Final EfficientNetB7 model and training history saved.")
# Out:
# Found 5221 images belonging to 2 classes.
# Found 1553 images belonging to 2 classes.
# 🛠 Building new EfficientNetB7 model...
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb7_notop.h5
# 258076736/258076736 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/15
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8021 - loss: 0.4034
# Epoch 1: saving model to /content/drive/MyDrive/TEfficientNetB7_checkpoint.keras
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 1351s 4s/step - accuracy: 0.8023 - loss: 0.4031 - val_accuracy: 0.9388 - val_loss: 0.1763 - learning_rate: 1.0000e-04
# Epoch 2/15
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9163 - loss: 0.2049
# Epoch 2: saving model to /content/drive/MyDrive/TEfficientNetB7_checkpoint.keras
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 417s 1s/step - accuracy: 0.9163 - loss: 0.2048 - val_accuracy: 0.9472 - val_loss: 0.1476 - learning_rate: 1.0000e-04
# Epoch 3/15
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9226 - loss: 0.1796
# Epoch 3: saving model to /content/drive/MyDrive/TEfficientNetB7_checkpoint.keras
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 420s 1s/step - accuracy: 0.9226 - loss: 0.1796 - val_accuracy: 0.9562 - val_loss: 0.1334 - learning_rate: 1.0000e-04
# Epoch 4/15
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9315 - loss: 0.1826
# Epoch 4: saving model to /content/drive/MyDrive/TEfficientNetB7_checkpoint.keras
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 415s 1s/step - accuracy: 0.9315 - loss: 0.1826 - val_accuracy: 0.9562 - val_loss: 0.1230 - learning_rate: 1.0000e-04
# Epoch 5/15
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9364 - loss: 0.1660
# Epoch 5: saving model to /content/drive/MyDrive/TEfficientNetB7_checkpoint.keras
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 413s 1s/step - accuracy: 0.9364 - loss: 0.1660 - val_accuracy: 0.9569 - val_loss: 0.1210 - learning_rate: 1.0000e-04
# Epoch 6/15
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9376 - loss: 0.1539
# Epoch 6: saving model to /content/drive/MyDrive/TEfficientNetB7_checkpoint.keras
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 411s 1s/step - accuracy: 0.9376 - loss: 0.1539 - val_accuracy: 0.9524 - val_loss: 0.1210 - learning_rate: 1.0000e-04
# Epoch 7/15
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9451 - loss: 0.1497
# Epoch 7: saving model to /content/drive/MyDrive/TEfficientNetB7_checkpoint.keras
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 423s 1s/step - accuracy: 0.9451 - loss: 0.1498 - val_accuracy: 0.9556 - val_loss: 0.1147 - learning_rate: 1.0000e-04
# Epoch 8/15
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9433 - loss: 0.1506
# Epoch 8: saving model to /content/drive/MyDrive/TEfficientNetB7_checkpoint.keras
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 414s 1s/step - accuracy: 0.9433 - loss: 0.1506 - val_accuracy: 0.9517 - val_loss: 0.1218 - learning_rate: 1.0000e-04
# Epoch 9/15
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9432 - loss: 0.1513
# Epoch 9: saving model to /content/drive/MyDrive/TEfficientNetB7_checkpoint.keras
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 415s 1s/step - accuracy: 0.9432 - loss: 0.1513 - val_accuracy: 0.9620 - val_loss: 0.1078 - learning_rate: 1.0000e-04
# Epoch 10/15
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9410 - loss: 0.1495
# Epoch 10: saving model to /content/drive/MyDrive/TEfficientNetB7_checkpoint.keras
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 414s 1s/step - accuracy: 0.9410 - loss: 0.1495 - val_accuracy: 0.9639 - val_loss: 0.1077 - learning_rate: 1.0000e-04
# Epoch 11/15
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9421 - loss: 0.1500
# Epoch 11: saving model to /content/drive/MyDrive/TEfficientNetB7_checkpoint.keras
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 416s 1s/step - accuracy: 0.9421 - loss: 0.1500 - val_accuracy: 0.9652 - val_loss: 0.1042 - learning_rate: 1.0000e-04
# Epoch 12/15
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9419 - loss: 0.1509
# Epoch 12: saving model to /content/drive/MyDrive/TEfficientNetB7_checkpoint.keras
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 413s 1s/step - accuracy: 0.9419 - loss: 0.1509 - val_accuracy: 0.9633 - val_loss: 0.1027 - learning_rate: 1.0000e-04
# Epoch 13/15
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9456 - loss: 0.1494
# Epoch 13: saving model to /content/drive/MyDrive/TEfficientNetB7_checkpoint.keras
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 414s 1s/step - accuracy: 0.9456 - loss: 0.1494 - val_accuracy: 0.9633 - val_loss: 0.1062 - learning_rate: 1.0000e-04
# Epoch 14/15
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9453 - loss: 0.1421
# Epoch 14: saving model to /content/drive/MyDrive/TEfficientNetB7_checkpoint.keras
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 416s 1s/step - accuracy: 0.9453 - loss: 0.1421 - val_accuracy: 0.9646 - val_loss: 0.1028 - learning_rate: 1.0000e-04
# Epoch 15/15
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9374 - loss: 0.1481
# Epoch 15: saving model to /content/drive/MyDrive/TEfficientNetB7_checkpoint.keras
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 2.9999999242136255e-05.
# 327/327 ━━━━━━━━━━━━━━━━━━━━ 414s 1s/step - accuracy: 0.9375 - loss: 0.1481 - val_accuracy: 0.9581 - val_loss: 0.1031 - learning_rate: 1.0000e-04
# Restoring model weights from the end of the best epoch: 12.
# ✅ Final EfficientNetB7 model and training history saved.

# %%
import pickle

# ✅ Load training history for EfficientNetB7
with open('/content/drive/MyDrive/TEfficientNetB7_history.pkl', 'rb') as f:
    history = pickle.load(f)

# ✅ Extract final epoch's training and validation accuracy
final_train_acc = history['accuracy'][-1]
final_val_acc = history['val_accuracy'][-1]

print(f"✅ Final Training Accuracy   : {final_train_acc * 100:.2f}%")
print(f"✅ Final Validation Accuracy : {final_val_acc * 100:.2f}%")
# Out:
# ✅ Final Training Accuracy   : 94.35%
# ✅ Final Validation Accuracy : 95.81%

# %%
import matplotlib.pyplot as plt
import pickle

# ✅ Load training history for EfficientNetB7
with open('/content/drive/MyDrive/TEfficientNetB7_history.pkl', 'rb') as f:
    history = pickle.load(f)

# ✅ Plot Accuracy
plt.figure(figsize=(8, 5))
plt.plot(history['accuracy'], label='Train Accuracy', linewidth=2)
plt.plot(history['val_accuracy'], label='Validation Accuracy', linewidth=2)
plt.title('EfficientNetB7 Accuracy per Epoch', fontsize=14)
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pickle

# ✅ Load training history for EfficientNetB7
with open('/content/drive/MyDrive/TEfficientNetB7_history.pkl', 'rb') as f:
    history = pickle.load(f)

# ✅ Plot Loss
plt.figure(figsize=(8, 5))
plt.plot(history['loss'], label='Train Loss', linewidth=2)
plt.plot(history['val_loss'], label='Validation Loss', linewidth=2)
plt.title('EfficientNetB7 Loss per Epoch', fontsize=14)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import os
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import load_model
from tensorflow.keras.applications.efficientnet import preprocess_input as efficientnet_preprocess

# -------- CONFIG -------- #
base_path = '/content/drive/MyDrive/Medical_Data/archive/chest_xray/chest_xray_split'
final_model_path = '/content/drive/MyDrive/TEfficientNetB7_final.keras'  # ✅ Updated for B7
batch_size = 16  # ✅ EfficientNetB7 is heavier; use lower batch size
input_shape = (600, 600, 3)  # ✅ Required input for EfficientNetB7

# -------- LOAD MODEL -------- #
model = load_model(final_model_path)

# -------- DATASET PREP -------- #
val_test_datagen = ImageDataGenerator(preprocessing_function=efficientnet_preprocess)

test_generator = val_test_datagen.flow_from_directory(
    os.path.join(base_path, 'test'),
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='binary',
    shuffle=False
)

# -------- EVALUATE -------- #
test_loss, test_accuracy = model.evaluate(test_generator)
print(f"✅ Test Accuracy: {test_accuracy * 100:.2f}%")
print(f"📉 Test Loss: {test_loss:.4f}")
# Out:
# Found 1556 images belonging to 2 classes.
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 334s 3s/step - accuracy: 0.9521 - loss: 0.1474
# ✅ Test Accuracy: 96.34%
# 📉 Test Loss: 0.1082

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, ConfusionMatrixDisplay

# -------- Step 1: True labels from generator -------- #
y_true = test_generator.classes

# -------- Step 2: Model predictions -------- #
y_pred_probs = model.predict(test_generator, verbose=1)

# -------- Step 3: Apply threshold (e.g. 0.5) -------- #
threshold = 0.50
y_pred = (y_pred_probs > threshold).astype(int).reshape(-1)

# -------- Step 4: Metrics -------- #
overall_accuracy  = accuracy_score(y_true, y_pred)
overall_precision = precision_score(y_true, y_pred)
overall_recall    = recall_score(y_true, y_pred)
overall_f1        = f1_score(y_true, y_pred)

# -------- Step 5: Print metrics -------- #
print("📊 Overall Model Performance (EfficientNetB7, Threshold = 0.50):\n")
print(f"✅ Accuracy :  {overall_accuracy:.4f}")
print(f"🎯 Precision: {overall_precision:.4f}")
print(f"🔁 Recall   : {overall_recall:.4f}")
print(f"📈 F1 Score : {overall_f1:.4f}")

# -------- Step 6: Confusion Matrix -------- #
cm = confusion_matrix(y_true, y_pred)
labels = list(test_generator.class_indices.keys())  # e.g. ['NORMAL', 'PNEUMONIA']

# -------- Step 7: Plot Confusion Matrix -------- #
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)
disp.plot(cmap=plt.cm.Blues)
plt.title("EfficientNetB7 - Confusion Matrix (Threshold = 0.50)")
plt.grid(False)
plt.show()

# -------- Step 8: TP, TN, FP, FN Breakdown -------- #
tn, fp, fn, tp = cm.ravel()

print("\n🧮 Confusion Matrix Breakdown:")
print(f"✅ True Positives (TP): {tp}")
print(f"✅ True Negatives (TN): {tn}")
print(f"❌ False Positives (FP): {fp}")
print(f"❌ False Negatives (FN): {fn}")
# Out:
# 98/98 ━━━━━━━━━━━━━━━━━━━━ 47s 317ms/step
# 📊 Overall Model Performance (EfficientNetB7, Threshold = 0.50):
#
# ✅ Accuracy :  0.9634
# 🎯 Precision: 0.9763
# 🔁 Recall   : 0.9737
# 📈 F1 Score : 0.9750
# 🧮 Confusion Matrix Breakdown:
# ✅ True Positives (TP): 1111
# ✅ True Negatives (TN): 388
# ❌ False Positives (FP): 27
# ❌ False Negatives (FN): 30
