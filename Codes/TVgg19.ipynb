# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !nvidia-smi
# Out:
# Mon Jul 21 08:23:03 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA L4                      Off |   00000000:00:03.0 Off |                    0 |
# | N/A   41C    P8             12W /   72W |       0MiB /  23034MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
import os

correct_path = '/content/drive/MyDrive/Medical_Data/archive/chest_xray/chest_xray_split'
print(os.listdir(correct_path))
# Out:
# ['train', 'val', 'test']

# %%
print("Train folders:", os.listdir(correct_path + '/train'))
print("Val folders:", os.listdir(correct_path + '/val'))
print("Test folders:", os.listdir(correct_path + '/test'))
# Out:
# Train folders: ['PNEUMONIA', 'NORMAL']
# Val folders: ['PNEUMONIA', 'NORMAL']
# Test folders: ['PNEUMONIA', 'NORMAL']

# %%
import os

base_path = '/content/drive/MyDrive/Medical_Data/archive/chest_xray/chest_xray_split'

splits = ['train', 'val', 'test']
classes = ['PNEUMONIA', 'NORMAL']

for split in splits:
    for cls in classes:
        folder = os.path.join(base_path, split, cls)
        count = len([f for f in os.listdir(folder) if f.lower().endswith(('.jpg', '.jpeg', '.png'))])
        print(f"{split.capitalize()} - {cls}: {count} images")
# Out:
# Train - PNEUMONIA: 3818 images
# Train - NORMAL: 1403 images
# Val - PNEUMONIA: 1135 images
# Val - NORMAL: 418 images
# Test - PNEUMONIA: 1141 images
# Test - NORMAL: 415 images

# %%
# ---------------- Step 1: Imports ---------------- #
import os
import pickle
import pandas as pd
from tensorflow.keras.applications import VGG19
from tensorflow.keras.applications.vgg19 import preprocess_input as vgg_preprocess
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dropout, Dense
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, EarlyStopping, ReduceLROnPlateau

# ✅ Optional: Mixed precision
from tensorflow.keras import mixed_precision
mixed_precision.set_global_policy('mixed_float16')

# ---------------- Step 2: Config ---------------- #
base_path = '/content/drive/MyDrive/Medical_Data/archive/chest_xray/chest_xray_split'
checkpoint_path = '/content/drive/MyDrive/TVGG19_checkpoint.keras'
final_model_path = '/content/drive/MyDrive/TVGG19_final.keras'
history_path = '/content/drive/MyDrive/TVGG19_history.pkl'
csv_log_path = '/content/drive/MyDrive/TVGG19_training_log.csv'

epochs = 20
batch_size = 64
input_shape = (224, 224, 3)
start_epoch = 0

# ---------------- Step 3: Data Generators ---------------- #
train_datagen = ImageDataGenerator(
    preprocessing_function=vgg_preprocess,
    rotation_range=15,
    zoom_range=0.1,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True
)

val_test_datagen = ImageDataGenerator(preprocessing_function=vgg_preprocess)

train_generator = train_datagen.flow_from_directory(
    os.path.join(base_path, 'train'),
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='binary'
)

val_generator = val_test_datagen.flow_from_directory(
    os.path.join(base_path, 'val'),
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='binary'
)

# ---------------- Step 4: Build Model ---------------- #
print("🛠 Building new VGG19 model...")
base_model = VGG19(weights='imagenet', include_top=False, input_shape=input_shape)
base_model.trainable = False  # Freeze convolutional base

x = GlobalAveragePooling2D()(base_model.output)
x = Dropout(0.5)(x)
x = Dense(128, activation='relu')(x)
x = Dropout(0.3)(x)
output = Dense(1, activation='sigmoid', dtype='float32')(x)  # Force float32 output

model = Model(inputs=base_model.input, outputs=output)
model.compile(optimizer=Adam(1e-4), loss='binary_crossentropy', metrics=['accuracy'])

# ---------------- Step 5: Callbacks ---------------- #
checkpoint_callback = ModelCheckpoint(
    filepath=checkpoint_path,
    save_best_only=False,
    save_weights_only=False,
    save_freq='epoch',
    verbose=1
)

csv_logger = CSVLogger(csv_log_path, append=False)

early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True, verbose=1)

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.3, patience=3, verbose=1)

# ---------------- Step 6: Train Model ---------------- #
history = model.fit(
    train_generator,
    validation_data=val_generator,
    initial_epoch=start_epoch,
    epochs=epochs,
    callbacks=[checkpoint_callback, csv_logger, early_stop, reduce_lr]
)

# ---------------- Step 7: Save Final Model & History ---------------- #
model.save(final_model_path)

with open(history_path, 'wb') as f:
    pickle.dump(history.history, f)

print("✅ Final VGG19 model and training history saved.")
# Out:
# Found 5221 images belonging to 2 classes.
# Found 1553 images belonging to 2 classes.
# 🛠 Building new VGG19 model...
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/20
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - accuracy: 0.5363 - loss: 2.4785
# Epoch 1: saving model to /content/drive/MyDrive/TVGG19_checkpoint.keras
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 1212s 15s/step - accuracy: 0.5371 - loss: 2.4725 - val_accuracy: 0.8216 - val_loss: 0.4605 - learning_rate: 1.0000e-04
# Epoch 2/20
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 768ms/step - accuracy: 0.7260 - loss: 1.1358
# Epoch 2: saving model to /content/drive/MyDrive/TVGG19_checkpoint.keras
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 69s 839ms/step - accuracy: 0.7262 - loss: 1.1344 - val_accuracy: 0.9182 - val_loss: 0.2125 - learning_rate: 1.0000e-04
# Epoch 3/20
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 771ms/step - accuracy: 0.7712 - loss: 0.8138
# Epoch 3: saving model to /content/drive/MyDrive/TVGG19_checkpoint.keras
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 69s 841ms/step - accuracy: 0.7715 - loss: 0.8124 - val_accuracy: 0.9311 - val_loss: 0.1754 - learning_rate: 1.0000e-04
# Epoch 4/20
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 772ms/step - accuracy: 0.8327 - loss: 0.5875
# Epoch 4: saving model to /content/drive/MyDrive/TVGG19_checkpoint.keras
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 69s 842ms/step - accuracy: 0.8327 - loss: 0.5874 - val_accuracy: 0.9253 - val_loss: 0.1933 - learning_rate: 1.0000e-04
# Epoch 5/20
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 769ms/step - accuracy: 0.8416 - loss: 0.5189
# Epoch 5: saving model to /content/drive/MyDrive/TVGG19_checkpoint.keras
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 69s 840ms/step - accuracy: 0.8416 - loss: 0.5188 - val_accuracy: 0.9356 - val_loss: 0.1635 - learning_rate: 1.0000e-04
# Epoch 6/20
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 772ms/step - accuracy: 0.8432 - loss: 0.5229
# Epoch 6: saving model to /content/drive/MyDrive/TVGG19_checkpoint.keras
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 69s 844ms/step - accuracy: 0.8433 - loss: 0.5225 - val_accuracy: 0.9395 - val_loss: 0.1612 - learning_rate: 1.0000e-04
# Epoch 7/20
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 775ms/step - accuracy: 0.8601 - loss: 0.4694
# Epoch 7: saving model to /content/drive/MyDrive/TVGG19_checkpoint.keras
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 69s 845ms/step - accuracy: 0.8601 - loss: 0.4692 - val_accuracy: 0.9382 - val_loss: 0.1595 - learning_rate: 1.0000e-04
# Epoch 8/20
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 772ms/step - accuracy: 0.8697 - loss: 0.4180
# Epoch 8: saving model to /content/drive/MyDrive/TVGG19_checkpoint.keras
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 69s 838ms/step - accuracy: 0.8697 - loss: 0.4178 - val_accuracy: 0.9440 - val_loss: 0.1504 - learning_rate: 1.0000e-04
# Epoch 9/20
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 773ms/step - accuracy: 0.8739 - loss: 0.3665
# Epoch 9: saving model to /content/drive/MyDrive/TVGG19_checkpoint.keras
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 70s 846ms/step - accuracy: 0.8739 - loss: 0.3667 - val_accuracy: 0.9440 - val_loss: 0.1504 - learning_rate: 1.0000e-04
# Epoch 10/20
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 766ms/step - accuracy: 0.8743 - loss: 0.3681
# Epoch 10: saving model to /content/drive/MyDrive/TVGG19_checkpoint.keras
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 69s 843ms/step - accuracy: 0.8743 - loss: 0.3680 - val_accuracy: 0.9453 - val_loss: 0.1493 - learning_rate: 1.0000e-04
# Epoch 11/20
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 770ms/step - accuracy: 0.8854 - loss: 0.3332
# Epoch 11: saving model to /content/drive/MyDrive/TVGG19_checkpoint.keras
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 69s 837ms/step - accuracy: 0.8854 - loss: 0.3334 - val_accuracy: 0.9433 - val_loss: 0.1533 - learning_rate: 1.0000e-04
# Epoch 12/20
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 772ms/step - accuracy: 0.8827 - loss: 0.3240
# Epoch 12: saving model to /content/drive/MyDrive/TVGG19_checkpoint.keras
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 69s 843ms/step - accuracy: 0.8827 - loss: 0.3240 - val_accuracy: 0.9466 - val_loss: 0.1543 - learning_rate: 1.0000e-04
# Epoch 13/20
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 770ms/step - accuracy: 0.8756 - loss: 0.3190
# Epoch 13: saving model to /content/drive/MyDrive/TVGG19_checkpoint.keras
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 2.9999999242136255e-05.
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 69s 839ms/step - accuracy: 0.8757 - loss: 0.3191 - val_accuracy: 0.9498 - val_loss: 0.1511 - learning_rate: 1.0000e-04
# Epoch 14/20
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 769ms/step - accuracy: 0.8784 - loss: 0.3278
# Epoch 14: saving model to /content/drive/MyDrive/TVGG19_checkpoint.keras
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 69s 837ms/step - accuracy: 0.8785 - loss: 0.3278 - val_accuracy: 0.9498 - val_loss: 0.1506 - learning_rate: 3.0000e-05
# Epoch 15/20
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 771ms/step - accuracy: 0.8836 - loss: 0.2912
# Epoch 15: saving model to /content/drive/MyDrive/TVGG19_checkpoint.keras
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 69s 839ms/step - accuracy: 0.8837 - loss: 0.2912 - val_accuracy: 0.9524 - val_loss: 0.1476 - learning_rate: 3.0000e-05
# Epoch 16/20
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 787ms/step - accuracy: 0.8833 - loss: 0.3047
# Epoch 16: saving model to /content/drive/MyDrive/TVGG19_checkpoint.keras
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 70s 857ms/step - accuracy: 0.8833 - loss: 0.3046 - val_accuracy: 0.9524 - val_loss: 0.1483 - learning_rate: 3.0000e-05
# Epoch 17/20
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 781ms/step - accuracy: 0.8938 - loss: 0.2955
# Epoch 17: saving model to /content/drive/MyDrive/TVGG19_checkpoint.keras
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 70s 849ms/step - accuracy: 0.8938 - loss: 0.2955 - val_accuracy: 0.9536 - val_loss: 0.1492 - learning_rate: 3.0000e-05
# Epoch 18/20
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 792ms/step - accuracy: 0.8871 - loss: 0.3049
# Epoch 18: saving model to /content/drive/MyDrive/TVGG19_checkpoint.keras
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 8.999999772640877e-06.
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 71s 866ms/step - accuracy: 0.8871 - loss: 0.3047 - val_accuracy: 0.9556 - val_loss: 0.1489 - learning_rate: 3.0000e-05
# Epoch 19/20
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 786ms/step - accuracy: 0.8873 - loss: 0.2967
# Epoch 19: saving model to /content/drive/MyDrive/TVGG19_checkpoint.keras
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 71s 858ms/step - accuracy: 0.8872 - loss: 0.2969 - val_accuracy: 0.9556 - val_loss: 0.1492 - learning_rate: 9.0000e-06
# Epoch 20/20
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 0s 781ms/step - accuracy: 0.8797 - loss: 0.3209
# Epoch 20: saving model to /content/drive/MyDrive/TVGG19_checkpoint.keras
# 82/82 ━━━━━━━━━━━━━━━━━━━━ 70s 850ms/step - accuracy: 0.8797 - loss: 0.3207 - val_accuracy: 0.9556 - val_loss: 0.1492 - learning_rate: 9.0000e-06
# Epoch 20: early stopping
# Restoring model weights from the end of the best epoch: 15.
# ✅ Final VGG19 model and training history saved.

# %%
import pickle

# ✅ Load training history for VGG19
with open('/content/drive/MyDrive/TVGG19_history.pkl', 'rb') as f:
    history = pickle.load(f)

# ✅ Extract final epoch's training and validation accuracy
final_train_acc = history['accuracy'][-1]
final_val_acc = history['val_accuracy'][-1]

print(f"✅ Final Training Accuracy   : {final_train_acc * 100:.2f}%")
print(f"✅ Final Validation Accuracy : {final_val_acc * 100:.2f}%")
# Out:
# ✅ Final Training Accuracy   : 88.49%
# ✅ Final Validation Accuracy : 95.56%

# %%
import matplotlib.pyplot as plt
import pickle

# ✅ Load training history for VGG19
with open('/content/drive/MyDrive/TVGG19_history.pkl', 'rb') as f:
    history = pickle.load(f)

# ✅ Plot Accuracy
plt.figure(figsize=(8, 5))
plt.plot(history['accuracy'], label='Train Accuracy', linewidth=2)
plt.plot(history['val_accuracy'], label='Validation Accuracy', linewidth=2)
plt.title('VGG19 Accuracy per Epoch', fontsize=14)
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pickle

# ✅ Load training history for VGG19
with open('/content/drive/MyDrive/TVGG19_history.pkl', 'rb') as f:
    history = pickle.load(f)

# ✅ Plot Loss
plt.figure(figsize=(8, 5))
plt.plot(history['loss'], label='Train Loss', linewidth=2)
plt.plot(history['val_loss'], label='Validation Loss', linewidth=2)
plt.title('VGG19 Loss per Epoch', fontsize=14)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import os
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import load_model
from tensorflow.keras.applications.vgg19 import preprocess_input as vgg_preprocess

# -------- CONFIG -------- #
base_path = '/content/drive/MyDrive/Medical_Data/archive/chest_xray/chest_xray_split'
final_model_path = '/content/drive/MyDrive/TVGG19_final.keras'  # ✅ Updated for VGG19
batch_size = 64  # ✅ Same as used during training
input_shape = (224, 224, 3)  # ✅ Required input for VGG19

# -------- LOAD MODEL -------- #
model = load_model(final_model_path)

# -------- DATASET PREP -------- #
val_test_datagen = ImageDataGenerator(preprocessing_function=vgg_preprocess)

test_generator = val_test_datagen.flow_from_directory(
    os.path.join(base_path, 'test'),
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='binary',
    shuffle=False
)

# -------- EVALUATE -------- #
test_loss, test_accuracy = model.evaluate(test_generator)
print(f"✅ Test Accuracy: {test_accuracy * 100:.2f}%")
print(f"📉 Test Loss: {test_loss:.4f}")
# Out:
# Found 1556 images belonging to 2 classes.
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 430s 18s/step - accuracy: 0.9362 - loss: 0.1909
# ✅ Test Accuracy: 94.73%
# 📉 Test Loss: 0.1522

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, ConfusionMatrixDisplay

# -------- Step 1: True labels from generator -------- #
y_true = test_generator.classes

# -------- Step 2: Model predictions -------- #
y_pred_probs = model.predict(test_generator, verbose=1)

# -------- Step 3: Apply threshold (e.g. 0.5) -------- #
threshold = 0.50
y_pred = (y_pred_probs > threshold).astype(int).reshape(-1)

# -------- Step 4: Metrics -------- #
overall_accuracy  = accuracy_score(y_true, y_pred)
overall_precision = precision_score(y_true, y_pred)
overall_recall    = recall_score(y_true, y_pred)
overall_f1        = f1_score(y_true, y_pred)

# -------- Step 5: Print metrics -------- #
print("📊 Overall Model Performance (VGG19, Threshold = 0.50):\n")
print(f"✅ Accuracy :  {overall_accuracy:.4f}")
print(f"🎯 Precision: {overall_precision:.4f}")
print(f"🔁 Recall   : {overall_recall:.4f}")
print(f"📈 F1 Score : {overall_f1:.4f}")

# -------- Step 6: Confusion Matrix -------- #
cm = confusion_matrix(y_true, y_pred)
labels = list(test_generator.class_indices.keys())  # e.g. ['NORMAL', 'PNEUMONIA']

# -------- Step 7: Plot Confusion Matrix -------- #
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)
disp.plot(cmap=plt.cm.Blues)
plt.title("VGG19 - Confusion Matrix (Threshold = 0.50)")
plt.grid(False)
plt.show()

# -------- Step 8: TP, TN, FP, FN Breakdown -------- #
tn, fp, fn, tp = cm.ravel()

print("\n🧮 Confusion Matrix Breakdown:")
print(f"✅ True Positives (TP): {tp}")
print(f"✅ True Negatives (TN): {tn}")
print(f"❌ False Positives (FP): {fp}")
print(f"❌ False Negatives (FN): {fn}")
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 232ms/step
# 📊 Overall Model Performance (VGG19, Threshold = 0.50):
#
# ✅ Accuracy :  0.9473
# 🎯 Precision: 0.9707
# 🔁 Recall   : 0.9571
# 📈 F1 Score : 0.9638
# 🧮 Confusion Matrix Breakdown:
# ✅ True Positives (TP): 1092
# ✅ True Negatives (TN): 382
# ❌ False Positives (FP): 33
# ❌ False Negatives (FN): 49
